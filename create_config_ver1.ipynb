# %%
import os
import json
import numpy as np

# %% [markdown]
# ### Find total num of subjects and file path for creating config.json later

# %%
# Get current working directory
current_dir = os.getcwd()

# Go into "data" folder and list all entries
app_dir = current_dir+"/data"
entries = os.listdir(app_dir)

# Initialize an empty list to store folder path and subjectID
folders = []
subjectID = []

# Iterate over all entries
LENGTH = len("sub-")
for entry in entries:
    # Check if the entry is a directory
    if os.path.isdir(os.path.join(app_dir, entry)):
        # If it is, add it to the list of folders
        subjectID.append(int(entry[LENGTH:]))
        folders.append("../data/" + entry + "/cortexmap")

# sort folder names alphabetically
folders.sort()

# Print num of folder to verify
print("Total number of folders: ", len(folders))
# Out:
# Total number of folders:  1062

# %% [markdown]
# ### Generate boostrap samples
#
# - Number of subjects = 1062
# - Number of bootstrap samples = 1000
# - So, there are 1000 samples. Each sample has 1062 input files (sampled with replacement)
# - Initial seed: 3212024171403

# %%
initial_seed = 3212024171403 # initial seed: 3212024171403

# Generate random seeds
rng = np.random.default_rng(initial_seed)
num_samples = 1000 # num of bootstrap samples = num of seeds
seeds = rng.choice(1000000000000000000, num_samples, replace=False) # includes 1 seed per sample

# Generate bootstrap samples
samples = [] # 2D arr. 1 row = 1 boostrap sample. 1 element = 1 subject = index folders arr

for seed in seeds:
    rng = np.random.default_rng(seed)
    total_subjects = len(folders) # total number of subjects = size of sample
    samples.append(rng.choice(total_subjects, total_subjects))

# print dimension of samples to verify
print("dimensions of bootstrap sample:")
print(len(samples))
print(len(samples[0]))
# Out:
# dimensions of bootstrap sample:
# 1000
# 1062

# %% [markdown]
# ### Create config.json file for fsaverage app

# %%
# Create list of folder paths for the 1000 bootstrap samples
counter = 1
for sample in samples:
    subjects = [] # folder paths for 1 boostrap sample
    for i in sample:
        subjects.append(folders[i])

    print("Number of input files: ", len(subjects)) # printing to confirm
    # Create a dictionary with "input" key (threshold and dilate set to 0)
    json_data = {"threshold" : 0,
                "dilate" : 0,
                "inputs": subjects}

    # Specify the output JSON file path (outputs to current directory)
    output_file_path = "config_s" + str(counter) + ".json"

    # Write data to JSON file
    with open(output_file_path, 'w') as f:
        json.dump(json_data, f, indent=4)

    print(f"Data has been written to {output_file_path}")
    counter += 1
# Out:
# Number of input files:  1062
# Data has been written to config_s1.json
# Number of input files:  1062
# Data has been written to config_s2.json
# Number of input files:  1062
# Data has been written to config_s3.json
# Number of input files:  1062
# Data has been written to config_s4.json
# Number of input files:  1062
# Data has been written to config_s5.json
# Number of input files:  1062
# Data has been written to config_s6.json
# Number of input files:  1062
# Data has been written to config_s7.json
# Number of input files:  1062
# Data has been written to config_s8.json
# Number of input files:  1062
# Data has been written to config_s9.json
# Number of input files:  1062
# Data has been written to config_s10.json
# Number of input files:  1062
# Data has been written to config_s11.json
# Number of input files:  1062
# Data has been written to config_s12.json
# Number of input files:  1062
# Data has been written to config_s13.json
# Number of input files:  1062
# Data has been written to config_s14.json
# Number of input files:  1062
# Data has been written to config_s15.json
# Number of input files:  1062
# Data has been written to config_s16.json
# Number of input files:  1062
# Data has been written to config_s17.json
# Number of input files:  1062
# Data has been written to config_s18.json
# Number of input files:  1062
# Data has been written to config_s19.json
# Number of input files:  1062
# Data has been written to config_s20.json
# Number of input files:  1062
# Data has been written to config_s21.json
# Number of input files:  1062
# Data has been written to config_s22.json
# Number of input files:  1062
# Data has been written to config_s23.json
# Number of input files:  1062
# Data has been written to config_s24.json
# Number of input files:  1062
# Data has been written to config_s25.json
# Number of input files:  1062
# Data has been written to config_s26.json
# Number of input files:  1062
# Data has been written to config_s27.json
# Number of input files:  1062
# Data has been written to config_s28.json
# Number of input files:  1062
# Data has been written to config_s29.json
# Number of input files:  1062
# Data has been written to config_s30.json
# Number of input files:  1062
# Data has been written to config_s31.json
# Number of input files:  1062
# Data has been written to config_s32.json
# Number of input files:  1062
# Data has been written to config_s33.json
# Number of input files:  1062
# Data has been written to config_s34.json
# Number of input files:  1062
# Data has been written to config_s35.json
# Number of input files:  1062
# Data has been written to config_s36.json
# Number of input files:  1062
# Data has been written to config_s37.json
# Number of input files:  1062
# Data has been written to config_s38.json
# Number of input files:  1062
# Data has been written to config_s39.json
# Number of input files:  1062
# Data has been written to config_s40.json
# Number of input files:  1062
# Data has been written to config_s41.json
# Number of input files:  1062
# Data has been written to config_s42.json
# Number of input files:  1062
# Data has been written to config_s43.json
# Number of input files:  1062
# Data has been written to config_s44.json
# Number of input files:  1062
# Data has been written to config_s45.json
# Number of input files:  1062
# Data has been written to config_s46.json
# Number of input files:  1062
# Data has been written to config_s47.json
# Number of input files:  1062
# Data has been written to config_s48.json
# Number of input files:  1062
# Data has been written to config_s49.json
# Number of input files:  1062
# Data has been written to config_s50.json
# Number of input files:  1062
# Data has been written to config_s51.json
# Number of input files:  1062
# Data has been written to config_s52.json
# Number of input files:  1062
# Data has been written to config_s53.json
# Number of input files:  1062
# Data has been written to config_s54.json
# Number of input files:  1062
# Data has been written to config_s55.json
# Number of input files:  1062
# Data has been written to config_s56.json
# Number of input files:  1062
# Data has been written to config_s57.json
# Number of input files:  1062
# Data has been written to config_s58.json
# Number of input files:  1062
# Data has been written to config_s59.json
# Number of input files:  1062
# Data has been written to config_s60.json
# Number of input files:  1062
# Data has been written to config_s61.json
# Number of input files:  1062
# Data has been written to config_s62.json
# Number of input files:  1062
# Data has been written to config_s63.json
# Number of input files:  1062
# Data has been written to config_s64.json
# Number of input files:  1062
# Data has been written to config_s65.json
# Number of input files:  1062
# Data has been written to config_s66.json
# Number of input files:  1062
# Data has been written to config_s67.json
# Number of input files:  1062
# Data has been written to config_s68.json
# Number of input files:  1062
# Data has been written to config_s69.json
# Number of input files:  1062
# Data has been written to config_s70.json
# Number of input files:  1062
# Data has been written to config_s71.json
# Number of input files:  1062
# Data has been written to config_s72.json
# Number of input files:  1062
# Data has been written to config_s73.json
# Number of input files:  1062
# Data has been written to config_s74.json
# Number of input files:  1062
# Data has been written to config_s75.json
# Number of input files:  1062
# Data has been written to config_s76.json
# Number of input files:  1062
# Data has been written to config_s77.json
# Number of input files:  1062
# Data has been written to config_s78.json
# Number of input files:  1062
# Data has been written to config_s79.json
# Number of input files:  1062
# Data has been written to config_s80.json
# Number of input files:  1062
# Data has been written to config_s81.json
# Number of input files:  1062
# Data has been written to config_s82.json
# Number of input files:  1062
# Data has been written to config_s83.json
# Number of input files:  1062
# Data has been written to config_s84.json
# Number of input files:  1062
# Data has been written to config_s85.json
# Number of input files:  1062
# Data has been written to config_s86.json
# Number of input files:  1062
# Data has been written to config_s87.json
# Number of input files:  1062
# Data has been written to config_s88.json
# Number of input files:  1062
# Data has been written to config_s89.json
# Number of input files:  1062
# Data has been written to config_s90.json
# Number of input files:  1062
# Data has been written to config_s91.json
# Number of input files:  1062
# Data has been written to config_s92.json
# Number of input files:  1062
# Data has been written to config_s93.json
# Number of input files:  1062
# Data has been written to config_s94.json
# Number of input files:  1062
# Data has been written to config_s95.json
# Number of input files:  1062
# Data has been written to config_s96.json
# Number of input files:  1062
# Data has been written to config_s97.json
# Number of input files:  1062
# Data has been written to config_s98.json
# Number of input files:  1062
# Data has been written to config_s99.json
# Number of input files:  1062
# Data has been written to config_s100.json
# Number of input files:  1062
# Data has been written to config_s101.json
# Number of input files:  1062
# Data has been written to config_s102.json
# Number of input files:  1062
# Data has been written to config_s103.json
# Number of input files:  1062
# Data has been written to config_s104.json
# Number of input files:  1062
# Data has been written to config_s105.json
# Number of input files:  1062
# Data has been written to config_s106.json
# Number of input files:  1062
# Data has been written to config_s107.json
# Number of input files:  1062
# Data has been written to config_s108.json
# Number of input files:  1062
# Data has been written to config_s109.json
# Number of input files:  1062
# Data has been written to config_s110.json
# Number of input files:  1062
# Data has been written to config_s111.json
# Number of input files:  1062
# Data has been written to config_s112.json
# Number of input files:  1062
# Data has been written to config_s113.json
# Number of input files:  1062
# Data has been written to config_s114.json
# Number of input files:  1062
# Data has been written to config_s115.json
# Number of input files:  1062
# Data has been written to config_s116.json
# Number of input files:  1062
# Data has been written to config_s117.json
# Number of input files:  1062
# Data has been written to config_s118.json
# Number of input files:  1062
# Data has been written to config_s119.json
# Number of input files:  1062
# Data has been written to config_s120.json
# Number of input files:  1062
# Data has been written to config_s121.json
# Number of input files:  1062
# Data has been written to config_s122.json
# Number of input files:  1062
# Data has been written to config_s123.json
# Number of input files:  1062
# Data has been written to config_s124.json
# Number of input files:  1062
# Data has been written to config_s125.json
# Number of input files:  1062
# Data has been written to config_s126.json
# Number of input files:  1062
# Data has been written to config_s127.json
# Number of input files:  1062
# Data has been written to config_s128.json
# Number of input files:  1062
# Data has been written to config_s129.json
# Number of input files:  1062
# Data has been written to config_s130.json
# Number of input files:  1062
# Data has been written to config_s131.json
# Number of input files:  1062
# Data has been written to config_s132.json
# Number of input files:  1062
# Data has been written to config_s133.json
# Number of input files:  1062
# Data has been written to config_s134.json
# Number of input files:  1062
# Data has been written to config_s135.json
# Number of input files:  1062
# Data has been written to config_s136.json
# Number of input files:  1062
# Data has been written to config_s137.json
# Number of input files:  1062
# Data has been written to config_s138.json
# Number of input files:  1062
# Data has been written to config_s139.json
# Number of input files:  1062
# Data has been written to config_s140.json
# Number of input files:  1062
# Data has been written to config_s141.json
# Number of input files:  1062
# Data has been written to config_s142.json
# Number of input files:  1062
# Data has been written to config_s143.json
# Number of input files:  1062
# Data has been written to config_s144.json
# Number of input files:  1062
# Data has been written to config_s145.json
# Number of input files:  1062
# Data has been written to config_s146.json
# Number of input files:  1062
# Data has been written to config_s147.json
# Number of input files:  1062
# Data has been written to config_s148.json
# Number of input files:  1062
# Data has been written to config_s149.json
# Number of input files:  1062
# Data has been written to config_s150.json
# Number of input files:  1062
# Data has been written to config_s151.json
# Number of input files:  1062
# Data has been written to config_s152.json
# Number of input files:  1062
# Data has been written to config_s153.json
# Number of input files:  1062
# Data has been written to config_s154.json
# Number of input files:  1062
# Data has been written to config_s155.json
# Number of input files:  1062
# Data has been written to config_s156.json
# Number of input files:  1062
# Data has been written to config_s157.json
# Number of input files:  1062
# Data has been written to config_s158.json
# Number of input files:  1062
# Data has been written to config_s159.json
# Number of input files:  1062
# Data has been written to config_s160.json
# Number of input files:  1062
# Data has been written to config_s161.json
# Number of input files:  1062
# Data has been written to config_s162.json
# Number of input files:  1062
# Data has been written to config_s163.json
# Number of input files:  1062
# Data has been written to config_s164.json
# Number of input files:  1062
# Data has been written to config_s165.json
# Number of input files:  1062
# Data has been written to config_s166.json
# Number of input files:  1062
# Data has been written to config_s167.json
# Number of input files:  1062
# Data has been written to config_s168.json
# Number of input files:  1062
# Data has been written to config_s169.json
# Number of input files:  1062
# Data has been written to config_s170.json
# Number of input files:  1062
# Data has been written to config_s171.json
# Number of input files:  1062
# Data has been written to config_s172.json
# Number of input files:  1062
# Data has been written to config_s173.json
# Number of input files:  1062
# Data has been written to config_s174.json
# Number of input files:  1062
# Data has been written to config_s175.json
# Number of input files:  1062
# Data has been written to config_s176.json
# Number of input files:  1062
# Data has been written to config_s177.json
# Number of input files:  1062
# Data has been written to config_s178.json
# Number of input files:  1062
# Data has been written to config_s179.json
# Number of input files:  1062
# Data has been written to config_s180.json
# Number of input files:  1062
# Data has been written to config_s181.json
# Number of input files:  1062
# Data has been written to config_s182.json
# Number of input files:  1062
# Data has been written to config_s183.json
# Number of input files:  1062
# Data has been written to config_s184.json
# Number of input files:  1062
# Data has been written to config_s185.json
# Number of input files:  1062
# Data has been written to config_s186.json
# Number of input files:  1062
# Data has been written to config_s187.json
# Number of input files:  1062
# Data has been written to config_s188.json
# Number of input files:  1062
# Data has been written to config_s189.json
# Number of input files:  1062
# Data has been written to config_s190.json
# Number of input files:  1062
# Data has been written to config_s191.json
# Number of input files:  1062
# Data has been written to config_s192.json
# Number of input files:  1062
# Data has been written to config_s193.json
# Number of input files:  1062
# Data has been written to config_s194.json
# Number of input files:  1062
# Data has been written to config_s195.json
# Number of input files:  1062
# Data has been written to config_s196.json
# Number of input files:  1062
# Data has been written to config_s197.json
# Number of input files:  1062
# Data has been written to config_s198.json
# Number of input files:  1062
# Data has been written to config_s199.json
# Number of input files:  1062
# Data has been written to config_s200.json
# Number of input files:  1062
# Data has been written to config_s201.json
# Number of input files:  1062
# Data has been written to config_s202.json
# Number of input files:  1062
# Data has been written to config_s203.json
# Number of input files:  1062
# Data has been written to config_s204.json
# Number of input files:  1062
# Data has been written to config_s205.json
# Number of input files:  1062
# Data has been written to config_s206.json
# Number of input files:  1062
# Data has been written to config_s207.json
# Number of input files:  1062
# Data has been written to config_s208.json
# Number of input files:  1062
# Data has been written to config_s209.json
# Number of input files:  1062
# Data has been written to config_s210.json
# Number of input files:  1062
# Data has been written to config_s211.json
# Number of input files:  1062
# Data has been written to config_s212.json
# Number of input files:  1062
# Data has been written to config_s213.json
# Number of input files:  1062
# Data has been written to config_s214.json
# Number of input files:  1062
# Data has been written to config_s215.json
# Number of input files:  1062
# Data has been written to config_s216.json
# Number of input files:  1062
# Data has been written to config_s217.json
# Number of input files:  1062
# Data has been written to config_s218.json
# Number of input files:  1062
# Data has been written to config_s219.json
# Number of input files:  1062
# Data has been written to config_s220.json
# Number of input files:  1062
# Data has been written to config_s221.json
# Number of input files:  1062
# Data has been written to config_s222.json
# Number of input files:  1062
# Data has been written to config_s223.json
# Number of input files:  1062
# Data has been written to config_s224.json
# Number of input files:  1062
# Data has been written to config_s225.json
# Number of input files:  1062
# Data has been written to config_s226.json
# Number of input files:  1062
# Data has been written to config_s227.json
# Number of input files:  1062
# Data has been written to config_s228.json
# Number of input files:  1062
# Data has been written to config_s229.json
# Number of input files:  1062
# Data has been written to config_s230.json
# Number of input files:  1062
# Data has been written to config_s231.json
# Number of input files:  1062
# Data has been written to config_s232.json
# Number of input files:  1062
# Data has been written to config_s233.json
# Number of input files:  1062
# Data has been written to config_s234.json
# Number of input files:  1062
# Data has been written to config_s235.json
# Number of input files:  1062
# Data has been written to config_s236.json
# Number of input files:  1062
# Data has been written to config_s237.json
# Number of input files:  1062
# Data has been written to config_s238.json
# Number of input files:  1062
# Data has been written to config_s239.json
# Number of input files:  1062
# Data has been written to config_s240.json
# Number of input files:  1062
# Data has been written to config_s241.json
# Number of input files:  1062
# Data has been written to config_s242.json
# Number of input files:  1062
# Data has been written to config_s243.json
# Number of input files:  1062
# Data has been written to config_s244.json
# Number of input files:  1062
# Data has been written to config_s245.json
# Number of input files:  1062
# Data has been written to config_s246.json
# Number of input files:  1062
# Data has been written to config_s247.json
# Number of input files:  1062
# Data has been written to config_s248.json
# Number of input files:  1062
# Data has been written to config_s249.json
# Number of input files:  1062
# Data has been written to config_s250.json
# Number of input files:  1062
# Data has been written to config_s251.json
# Number of input files:  1062
# Data has been written to config_s252.json
# Number of input files:  1062
# Data has been written to config_s253.json
# Number of input files:  1062
# Data has been written to config_s254.json
# Number of input files:  1062
# Data has been written to config_s255.json
# Number of input files:  1062
# Data has been written to config_s256.json
# Number of input files:  1062
# Data has been written to config_s257.json
# Number of input files:  1062
# Data has been written to config_s258.json
# Number of input files:  1062
# Data has been written to config_s259.json
# Number of input files:  1062
# Data has been written to config_s260.json
# Number of input files:  1062
# Data has been written to config_s261.json
# Number of input files:  1062
# Data has been written to config_s262.json
# Number of input files:  1062
# Data has been written to config_s263.json
# Number of input files:  1062
# Data has been written to config_s264.json
# Number of input files:  1062
# Data has been written to config_s265.json
# Number of input files:  1062
# Data has been written to config_s266.json
# Number of input files:  1062
# Data has been written to config_s267.json
# Number of input files:  1062
# Data has been written to config_s268.json
# Number of input files:  1062
# Data has been written to config_s269.json
# Number of input files:  1062
# Data has been written to config_s270.json
# Number of input files:  1062
# Data has been written to config_s271.json
# Number of input files:  1062
# Data has been written to config_s272.json
# Number of input files:  1062
# Data has been written to config_s273.json
# Number of input files:  1062
# Data has been written to config_s274.json
# Number of input files:  1062
# Data has been written to config_s275.json
# Number of input files:  1062
# Data has been written to config_s276.json
# Number of input files:  1062
# Data has been written to config_s277.json
# Number of input files:  1062
# Data has been written to config_s278.json
# Number of input files:  1062
# Data has been written to config_s279.json
# Number of input files:  1062
# Data has been written to config_s280.json
# Number of input files:  1062
# Data has been written to config_s281.json
# Number of input files:  1062
# Data has been written to config_s282.json
# Number of input files:  1062
# Data has been written to config_s283.json
# Number of input files:  1062
# Data has been written to config_s284.json
# Number of input files:  1062
# Data has been written to config_s285.json
# Number of input files:  1062
# Data has been written to config_s286.json
# Number of input files:  1062
# Data has been written to config_s287.json
# Number of input files:  1062
# Data has been written to config_s288.json
# Number of input files:  1062
# Data has been written to config_s289.json
# Number of input files:  1062
# Data has been written to config_s290.json
# Number of input files:  1062
# Data has been written to config_s291.json
# Number of input files:  1062
# Data has been written to config_s292.json
# Number of input files:  1062
# Data has been written to config_s293.json
# Number of input files:  1062
# Data has been written to config_s294.json
# Number of input files:  1062
# Data has been written to config_s295.json
# Number of input files:  1062
# Data has been written to config_s296.json
# Number of input files:  1062
# Data has been written to config_s297.json
# Number of input files:  1062
# Data has been written to config_s298.json
# Number of input files:  1062
# Data has been written to config_s299.json
# Number of input files:  1062
# Data has been written to config_s300.json
# Number of input files:  1062
# Data has been written to config_s301.json
# Number of input files:  1062
# Data has been written to config_s302.json
# Number of input files:  1062
# Data has been written to config_s303.json
# Number of input files:  1062
# Data has been written to config_s304.json
# Number of input files:  1062
# Data has been written to config_s305.json
# Number of input files:  1062
# Data has been written to config_s306.json
# Number of input files:  1062
# Data has been written to config_s307.json
# Number of input files:  1062
# Data has been written to config_s308.json
# Number of input files:  1062
# Data has been written to config_s309.json
# Number of input files:  1062
# Data has been written to config_s310.json
# Number of input files:  1062
# Data has been written to config_s311.json
# Number of input files:  1062
# Data has been written to config_s312.json
# Number of input files:  1062
# Data has been written to config_s313.json
# Number of input files:  1062
# Data has been written to config_s314.json
# Number of input files:  1062
# Data has been written to config_s315.json
# Number of input files:  1062
# Data has been written to config_s316.json
# Number of input files:  1062
# Data has been written to config_s317.json
# Number of input files:  1062
# Data has been written to config_s318.json
# Number of input files:  1062
# Data has been written to config_s319.json
# Number of input files:  1062
# Data has been written to config_s320.json
# Number of input files:  1062
# Data has been written to config_s321.json
# Number of input files:  1062
# Data has been written to config_s322.json
# Number of input files:  1062
# Data has been written to config_s323.json
# Number of input files:  1062
# Data has been written to config_s324.json
# Number of input files:  1062
# Data has been written to config_s325.json
# Number of input files:  1062
# Data has been written to config_s326.json
# Number of input files:  1062
# Data has been written to config_s327.json
# Number of input files:  1062
# Data has been written to config_s328.json
# Number of input files:  1062
# Data has been written to config_s329.json
# Number of input files:  1062
# Data has been written to config_s330.json
# Number of input files:  1062
# Data has been written to config_s331.json
# Number of input files:  1062
# Data has been written to config_s332.json
# Number of input files:  1062
# Data has been written to config_s333.json
# Number of input files:  1062
# Data has been written to config_s334.json
# Number of input files:  1062
# Data has been written to config_s335.json
# Number of input files:  1062
# Data has been written to config_s336.json
# Number of input files:  1062
# Data has been written to config_s337.json
# Number of input files:  1062
# Data has been written to config_s338.json
# Number of input files:  1062
# Data has been written to config_s339.json
# Number of input files:  1062
# Data has been written to config_s340.json
# Number of input files:  1062
# Data has been written to config_s341.json
# Number of input files:  1062
# Data has been written to config_s342.json
# Number of input files:  1062
# Data has been written to config_s343.json
# Number of input files:  1062
# Data has been written to config_s344.json
# Number of input files:  1062
# Data has been written to config_s345.json
# Number of input files:  1062
# Data has been written to config_s346.json
# Number of input files:  1062
# Data has been written to config_s347.json
# Number of input files:  1062
# Data has been written to config_s348.json
# Number of input files:  1062
# Data has been written to config_s349.json
# Number of input files:  1062
# Data has been written to config_s350.json
# Number of input files:  1062
# Data has been written to config_s351.json
# Number of input files:  1062
# Data has been written to config_s352.json
# Number of input files:  1062
# Data has been written to config_s353.json
# Number of input files:  1062
# Data has been written to config_s354.json
# Number of input files:  1062
# Data has been written to config_s355.json
# Number of input files:  1062
# Data has been written to config_s356.json
# Number of input files:  1062
# Data has been written to config_s357.json
# Number of input files:  1062
# Data has been written to config_s358.json
# Number of input files:  1062
# Data has been written to config_s359.json
# Number of input files:  1062
# Data has been written to config_s360.json
# Number of input files:  1062
# Data has been written to config_s361.json
# Number of input files:  1062
# Data has been written to config_s362.json
# Number of input files:  1062
# Data has been written to config_s363.json
# Number of input files:  1062
# Data has been written to config_s364.json
# Number of input files:  1062
# Data has been written to config_s365.json
# Number of input files:  1062
# Data has been written to config_s366.json
# Number of input files:  1062
# Data has been written to config_s367.json
# Number of input files:  1062
# Data has been written to config_s368.json
# Number of input files:  1062
# Data has been written to config_s369.json
# Number of input files:  1062
# Data has been written to config_s370.json
# Number of input files:  1062
# Data has been written to config_s371.json
# Number of input files:  1062
# Data has been written to config_s372.json
# Number of input files:  1062
# Data has been written to config_s373.json
# Number of input files:  1062
# Data has been written to config_s374.json
# Number of input files:  1062
# Data has been written to config_s375.json
# Number of input files:  1062
# Data has been written to config_s376.json
# Number of input files:  1062
# Data has been written to config_s377.json
# Number of input files:  1062
# Data has been written to config_s378.json
# Number of input files:  1062
# Data has been written to config_s379.json
# Number of input files:  1062
# Data has been written to config_s380.json
# Number of input files:  1062
# Data has been written to config_s381.json
# Number of input files:  1062
# Data has been written to config_s382.json
# Number of input files:  1062
# Data has been written to config_s383.json
# Number of input files:  1062
# Data has been written to config_s384.json
# Number of input files:  1062
# Data has been written to config_s385.json
# Number of input files:  1062
# Data has been written to config_s386.json
# Number of input files:  1062
# Data has been written to config_s387.json
# Number of input files:  1062
# Data has been written to config_s388.json
# Number of input files:  1062
# Data has been written to config_s389.json
# Number of input files:  1062
# Data has been written to config_s390.json
# Number of input files:  1062
# Data has been written to config_s391.json
# Number of input files:  1062
# Data has been written to config_s392.json
# Number of input files:  1062
# Data has been written to config_s393.json
# Number of input files:  1062
# Data has been written to config_s394.json
# Number of input files:  1062
# Data has been written to config_s395.json
# Number of input files:  1062
# Data has been written to config_s396.json
# Number of input files:  1062
# Data has been written to config_s397.json
# Number of input files:  1062
# Data has been written to config_s398.json
# Number of input files:  1062
# Data has been written to config_s399.json
# Number of input files:  1062
# Data has been written to config_s400.json
# Number of input files:  1062
# Data has been written to config_s401.json
# Number of input files:  1062
# Data has been written to config_s402.json
# Number of input files:  1062
# Data has been written to config_s403.json
# Number of input files:  1062
# Data has been written to config_s404.json
# Number of input files:  1062
# Data has been written to config_s405.json
# Number of input files:  1062
# Data has been written to config_s406.json
# Number of input files:  1062
# Data has been written to config_s407.json
# Number of input files:  1062
# Data has been written to config_s408.json
# Number of input files:  1062
# Data has been written to config_s409.json
# Number of input files:  1062
# Data has been written to config_s410.json
# Number of input files:  1062
# Data has been written to config_s411.json
# Number of input files:  1062
# Data has been written to config_s412.json
# Number of input files:  1062
# Data has been written to config_s413.json
# Number of input files:  1062
# Data has been written to config_s414.json
# Number of input files:  1062
# Data has been written to config_s415.json
# Number of input files:  1062
# Data has been written to config_s416.json
# Number of input files:  1062
# Data has been written to config_s417.json
# Number of input files:  1062
# Data has been written to config_s418.json
# Number of input files:  1062
# Data has been written to config_s419.json
# Number of input files:  1062
# Data has been written to config_s420.json
# Number of input files:  1062
# Data has been written to config_s421.json
# Number of input files:  1062
# Data has been written to config_s422.json
# Number of input files:  1062
# Data has been written to config_s423.json
# Number of input files:  1062
# Data has been written to config_s424.json
# Number of input files:  1062
# Data has been written to config_s425.json
# Number of input files:  1062
# Data has been written to config_s426.json
# Number of input files:  1062
# Data has been written to config_s427.json
# Number of input files:  1062
# Data has been written to config_s428.json
# Number of input files:  1062
# Data has been written to config_s429.json
# Number of input files:  1062
# Data has been written to config_s430.json
# Number of input files:  1062
# Data has been written to config_s431.json
# Number of input files:  1062
# Data has been written to config_s432.json
# Number of input files:  1062
# Data has been written to config_s433.json
# Number of input files:  1062
# Data has been written to config_s434.json
# Number of input files:  1062
# Data has been written to config_s435.json
# Number of input files:  1062
# Data has been written to config_s436.json
# Number of input files:  1062
# Data has been written to config_s437.json
# Number of input files:  1062
# Data has been written to config_s438.json
# Number of input files:  1062
# Data has been written to config_s439.json
# Number of input files:  1062
# Data has been written to config_s440.json
# Number of input files:  1062
# Data has been written to config_s441.json
# Number of input files:  1062
# Data has been written to config_s442.json
# Number of input files:  1062
# Data has been written to config_s443.json
# Number of input files:  1062
# Data has been written to config_s444.json
# Number of input files:  1062
# Data has been written to config_s445.json
# Number of input files:  1062
# Data has been written to config_s446.json
# Number of input files:  1062
# Data has been written to config_s447.json
# Number of input files:  1062
# Data has been written to config_s448.json
# Number of input files:  1062
# Data has been written to config_s449.json
# Number of input files:  1062
# Data has been written to config_s450.json
# Number of input files:  1062
# Data has been written to config_s451.json
# Number of input files:  1062
# Data has been written to config_s452.json
# Number of input files:  1062
# Data has been written to config_s453.json
# Number of input files:  1062
# Data has been written to config_s454.json
# Number of input files:  1062
# Data has been written to config_s455.json
# Number of input files:  1062
# Data has been written to config_s456.json
# Number of input files:  1062
# Data has been written to config_s457.json
# Number of input files:  1062
# Data has been written to config_s458.json
# Number of input files:  1062
# Data has been written to config_s459.json
# Number of input files:  1062
# Data has been written to config_s460.json
# Number of input files:  1062
# Data has been written to config_s461.json
# Number of input files:  1062
# Data has been written to config_s462.json
# Number of input files:  1062
# Data has been written to config_s463.json
# Number of input files:  1062
# Data has been written to config_s464.json
# Number of input files:  1062
# Data has been written to config_s465.json
# Number of input files:  1062
# Data has been written to config_s466.json
# Number of input files:  1062
# Data has been written to config_s467.json
# Number of input files:  1062
# Data has been written to config_s468.json
# Number of input files:  1062
# Data has been written to config_s469.json
# Number of input files:  1062
# Data has been written to config_s470.json
# Number of input files:  1062
# Data has been written to config_s471.json
# Number of input files:  1062
# Data has been written to config_s472.json
# Number of input files:  1062
# Data has been written to config_s473.json
# Number of input files:  1062
# Data has been written to config_s474.json
# Number of input files:  1062
# Data has been written to config_s475.json
# Number of input files:  1062
# Data has been written to config_s476.json
# Number of input files:  1062
# Data has been written to config_s477.json
# Number of input files:  1062
# Data has been written to config_s478.json
# Number of input files:  1062
# Data has been written to config_s479.json
# Number of input files:  1062
# Data has been written to config_s480.json
# Number of input files:  1062
# Data has been written to config_s481.json
# Number of input files:  1062
# Data has been written to config_s482.json
# Number of input files:  1062
# Data has been written to config_s483.json
# Number of input files:  1062
# Data has been written to config_s484.json
# Number of input files:  1062
# Data has been written to config_s485.json
# Number of input files:  1062
# Data has been written to config_s486.json
# Number of input files:  1062
# Data has been written to config_s487.json
# Number of input files:  1062
# Data has been written to config_s488.json
# Number of input files:  1062
# Data has been written to config_s489.json
# Number of input files:  1062
# Data has been written to config_s490.json
# Number of input files:  1062
# Data has been written to config_s491.json
# Number of input files:  1062
# Data has been written to config_s492.json
# Number of input files:  1062
# Data has been written to config_s493.json
# Number of input files:  1062
# Data has been written to config_s494.json
# Number of input files:  1062
# Data has been written to config_s495.json
# Number of input files:  1062
# Data has been written to config_s496.json
# Number of input files:  1062
# Data has been written to config_s497.json
# Number of input files:  1062
# Data has been written to config_s498.json
# Number of input files:  1062
# Data has been written to config_s499.json
# Number of input files:  1062
# Data has been written to config_s500.json
# Number of input files:  1062
# Data has been written to config_s501.json
# Number of input files:  1062
# Data has been written to config_s502.json
# Number of input files:  1062
# Data has been written to config_s503.json
# Number of input files:  1062
# Data has been written to config_s504.json
# Number of input files:  1062
# Data has been written to config_s505.json
# Number of input files:  1062
# Data has been written to config_s506.json
# Number of input files:  1062
# Data has been written to config_s507.json
# Number of input files:  1062
# Data has been written to config_s508.json
# Number of input files:  1062
# Data has been written to config_s509.json
# Number of input files:  1062
# Data has been written to config_s510.json
# Number of input files:  1062
# Data has been written to config_s511.json
# Number of input files:  1062
# Data has been written to config_s512.json
# Number of input files:  1062
# Data has been written to config_s513.json
# Number of input files:  1062
# Data has been written to config_s514.json
# Number of input files:  1062
# Data has been written to config_s515.json
# Number of input files:  1062
# Data has been written to config_s516.json
# Number of input files:  1062
# Data has been written to config_s517.json
# Number of input files:  1062
# Data has been written to config_s518.json
# Number of input files:  1062
# Data has been written to config_s519.json
# Number of input files:  1062
# Data has been written to config_s520.json
# Number of input files:  1062
# Data has been written to config_s521.json
# Number of input files:  1062
# Data has been written to config_s522.json
# Number of input files:  1062
# Data has been written to config_s523.json
# Number of input files:  1062
# Data has been written to config_s524.json
# Number of input files:  1062
# Data has been written to config_s525.json
# Number of input files:  1062
# Data has been written to config_s526.json
# Number of input files:  1062
# Data has been written to config_s527.json
# Number of input files:  1062
# Data has been written to config_s528.json
# Number of input files:  1062
# Data has been written to config_s529.json
# Number of input files:  1062
# Data has been written to config_s530.json
# Number of input files:  1062
# Data has been written to config_s531.json
# Number of input files:  1062
# Data has been written to config_s532.json
# Number of input files:  1062
# Data has been written to config_s533.json
# Number of input files:  1062
# Data has been written to config_s534.json
# Number of input files:  1062
# Data has been written to config_s535.json
# Number of input files:  1062
# Data has been written to config_s536.json
# Number of input files:  1062
# Data has been written to config_s537.json
# Number of input files:  1062
# Data has been written to config_s538.json
# Number of input files:  1062
# Data has been written to config_s539.json
# Number of input files:  1062
# Data has been written to config_s540.json
# Number of input files:  1062
# Data has been written to config_s541.json
# Number of input files:  1062
# Data has been written to config_s542.json
# Number of input files:  1062
# Data has been written to config_s543.json
# Number of input files:  1062
# Data has been written to config_s544.json
# Number of input files:  1062
# Data has been written to config_s545.json
# Number of input files:  1062
# Data has been written to config_s546.json
# Number of input files:  1062
# Data has been written to config_s547.json
# Number of input files:  1062
# Data has been written to config_s548.json
# Number of input files:  1062
# Data has been written to config_s549.json
# Number of input files:  1062
# Data has been written to config_s550.json
# Number of input files:  1062
# Data has been written to config_s551.json
# Number of input files:  1062
# Data has been written to config_s552.json
# Number of input files:  1062
# Data has been written to config_s553.json
# Number of input files:  1062
# Data has been written to config_s554.json
# Number of input files:  1062
# Data has been written to config_s555.json
# Number of input files:  1062
# Data has been written to config_s556.json
# Number of input files:  1062
# Data has been written to config_s557.json
# Number of input files:  1062
# Data has been written to config_s558.json
# Number of input files:  1062
# Data has been written to config_s559.json
# Number of input files:  1062
# Data has been written to config_s560.json
# Number of input files:  1062
# Data has been written to config_s561.json
# Number of input files:  1062
# Data has been written to config_s562.json
# Number of input files:  1062
# Data has been written to config_s563.json
# Number of input files:  1062
# Data has been written to config_s564.json
# Number of input files:  1062
# Data has been written to config_s565.json
# Number of input files:  1062
# Data has been written to config_s566.json
# Number of input files:  1062
# Data has been written to config_s567.json
# Number of input files:  1062
# Data has been written to config_s568.json
# Number of input files:  1062
# Data has been written to config_s569.json
# Number of input files:  1062
# Data has been written to config_s570.json
# Number of input files:  1062
# Data has been written to config_s571.json
# Number of input files:  1062
# Data has been written to config_s572.json
# Number of input files:  1062
# Data has been written to config_s573.json
# Number of input files:  1062
# Data has been written to config_s574.json
# Number of input files:  1062
# Data has been written to config_s575.json
# Number of input files:  1062
# Data has been written to config_s576.json
# Number of input files:  1062
# Data has been written to config_s577.json
# Number of input files:  1062
# Data has been written to config_s578.json
# Number of input files:  1062
# Data has been written to config_s579.json
# Number of input files:  1062
# Data has been written to config_s580.json
# Number of input files:  1062
# Data has been written to config_s581.json
# Number of input files:  1062
# Data has been written to config_s582.json
# Number of input files:  1062
# Data has been written to config_s583.json
# Number of input files:  1062
# Data has been written to config_s584.json
# Number of input files:  1062
# Data has been written to config_s585.json
# Number of input files:  1062
# Data has been written to config_s586.json
# Number of input files:  1062
# Data has been written to config_s587.json
# Number of input files:  1062
# Data has been written to config_s588.json
# Number of input files:  1062
# Data has been written to config_s589.json
# Number of input files:  1062
# Data has been written to config_s590.json
# Number of input files:  1062
# Data has been written to config_s591.json
# Number of input files:  1062
# Data has been written to config_s592.json
# Number of input files:  1062
# Data has been written to config_s593.json
# Number of input files:  1062
# Data has been written to config_s594.json
# Number of input files:  1062
# Data has been written to config_s595.json
# Number of input files:  1062
# Data has been written to config_s596.json
# Number of input files:  1062
# Data has been written to config_s597.json
# Number of input files:  1062
# Data has been written to config_s598.json
# Number of input files:  1062
# Data has been written to config_s599.json
# Number of input files:  1062
# Data has been written to config_s600.json
# Number of input files:  1062
# Data has been written to config_s601.json
# Number of input files:  1062
# Data has been written to config_s602.json
# Number of input files:  1062
# Data has been written to config_s603.json
# Number of input files:  1062
# Data has been written to config_s604.json
# Number of input files:  1062
# Data has been written to config_s605.json
# Number of input files:  1062
# Data has been written to config_s606.json
# Number of input files:  1062
# Data has been written to config_s607.json
# Number of input files:  1062
# Data has been written to config_s608.json
# Number of input files:  1062
# Data has been written to config_s609.json
# Number of input files:  1062
# Data has been written to config_s610.json
# Number of input files:  1062
# Data has been written to config_s611.json
# Number of input files:  1062
# Data has been written to config_s612.json
# Number of input files:  1062
# Data has been written to config_s613.json
# Number of input files:  1062
# Data has been written to config_s614.json
# Number of input files:  1062
# Data has been written to config_s615.json
# Number of input files:  1062
# Data has been written to config_s616.json
# Number of input files:  1062
# Data has been written to config_s617.json
# Number of input files:  1062
# Data has been written to config_s618.json
# Number of input files:  1062
# Data has been written to config_s619.json
# Number of input files:  1062
# Data has been written to config_s620.json
# Number of input files:  1062
# Data has been written to config_s621.json
# Number of input files:  1062
# Data has been written to config_s622.json
# Number of input files:  1062
# Data has been written to config_s623.json
# Number of input files:  1062
# Data has been written to config_s624.json
# Number of input files:  1062
# Data has been written to config_s625.json
# Number of input files:  1062
# Data has been written to config_s626.json
# Number of input files:  1062
# Data has been written to config_s627.json
# Number of input files:  1062
# Data has been written to config_s628.json
# Number of input files:  1062
# Data has been written to config_s629.json
# Number of input files:  1062
# Data has been written to config_s630.json
# Number of input files:  1062
# Data has been written to config_s631.json
# Number of input files:  1062
# Data has been written to config_s632.json
# Number of input files:  1062
# Data has been written to config_s633.json
# Number of input files:  1062
# Data has been written to config_s634.json
# Number of input files:  1062
# Data has been written to config_s635.json
# Number of input files:  1062
# Data has been written to config_s636.json
# Number of input files:  1062
# Data has been written to config_s637.json
# Number of input files:  1062
# Data has been written to config_s638.json
# Number of input files:  1062
# Data has been written to config_s639.json
# Number of input files:  1062
# Data has been written to config_s640.json
# Number of input files:  1062
# Data has been written to config_s641.json
# Number of input files:  1062
# Data has been written to config_s642.json
# Number of input files:  1062
# Data has been written to config_s643.json
# Number of input files:  1062
# Data has been written to config_s644.json
# Number of input files:  1062
# Data has been written to config_s645.json
# Number of input files:  1062
# Data has been written to config_s646.json
# Number of input files:  1062
# Data has been written to config_s647.json
# Number of input files:  1062
# Data has been written to config_s648.json
# Number of input files:  1062
# Data has been written to config_s649.json
# Number of input files:  1062
# Data has been written to config_s650.json
# Number of input files:  1062
# Data has been written to config_s651.json
# Number of input files:  1062
# Data has been written to config_s652.json
# Number of input files:  1062
# Data has been written to config_s653.json
# Number of input files:  1062
# Data has been written to config_s654.json
# Number of input files:  1062
# Data has been written to config_s655.json
# Number of input files:  1062
# Data has been written to config_s656.json
# Number of input files:  1062
# Data has been written to config_s657.json
# Number of input files:  1062
# Data has been written to config_s658.json
# Number of input files:  1062
# Data has been written to config_s659.json
# Number of input files:  1062
# Data has been written to config_s660.json
# Number of input files:  1062
# Data has been written to config_s661.json
# Number of input files:  1062
# Data has been written to config_s662.json
# Number of input files:  1062
# Data has been written to config_s663.json
# Number of input files:  1062
# Data has been written to config_s664.json
# Number of input files:  1062
# Data has been written to config_s665.json
# Number of input files:  1062
# Data has been written to config_s666.json
# Number of input files:  1062
# Data has been written to config_s667.json
# Number of input files:  1062
# Data has been written to config_s668.json
# Number of input files:  1062
# Data has been written to config_s669.json
# Number of input files:  1062
# Data has been written to config_s670.json
# Number of input files:  1062
# Data has been written to config_s671.json
# Number of input files:  1062
# Data has been written to config_s672.json
# Number of input files:  1062
# Data has been written to config_s673.json
# Number of input files:  1062
# Data has been written to config_s674.json
# Number of input files:  1062
# Data has been written to config_s675.json
# Number of input files:  1062
# Data has been written to config_s676.json
# Number of input files:  1062
# Data has been written to config_s677.json
# Number of input files:  1062
# ...
# Number of input files:  1062
# Data has been written to config_s776.json
# Number of input files:  1062
# Data has been written to config_s777.json
# Number of input files:  1062
# Data has been written to config_s778.json
# Number of input files:  1062
# Data has been written to config_s779.json
# Number of input files:  1062
# Data has been written to config_s780.json
# Number of input files:  1062
# Data has been written to config_s781.json
# Number of input files:  1062
# Data has been written to config_s782.json
# Number of input files:  1062
# Data has been written to config_s783.json
# Number of input files:  1062
# Data has been written to config_s784.json
# Number of input files:  1062
# Data has been written to config_s785.json
# Number of input files:  1062
# Data has been written to config_s786.json
# Number of input files:  1062
# Data has been written to config_s787.json
# Number of input files:  1062
# Data has been written to config_s788.json
# Number of input files:  1062
# Data has been written to config_s789.json
# Number of input files:  1062
# Data has been written to config_s790.json
# Number of input files:  1062
# Data has been written to config_s791.json
# Number of input files:  1062
# Data has been written to config_s792.json
# Number of input files:  1062
# Data has been written to config_s793.json
# Number of input files:  1062
# Data has been written to config_s794.json
# Number of input files:  1062
# Data has been written to config_s795.json
# Number of input files:  1062
# Data has been written to config_s796.json
# Number of input files:  1062
# Data has been written to config_s797.json
# Number of input files:  1062
# Data has been written to config_s798.json
# Number of input files:  1062
# Data has been written to config_s799.json
# Number of input files:  1062
# Data has been written to config_s800.json
# Number of input files:  1062
# Data has been written to config_s801.json
# Number of input files:  1062
# Data has been written to config_s802.json
# Number of input files:  1062
# Data has been written to config_s803.json
# Number of input files:  1062
# Data has been written to config_s804.json
# Number of input files:  1062
# Data has been written to config_s805.json
# Number of input files:  1062
# Data has been written to config_s806.json
# Number of input files:  1062
# Data has been written to config_s807.json
# Number of input files:  1062
# Data has been written to config_s808.json
# Number of input files:  1062
# Data has been written to config_s809.json
# Number of input files:  1062
# Data has been written to config_s810.json
# Number of input files:  1062
# Data has been written to config_s811.json
# Number of input files:  1062
# Data has been written to config_s812.json
# Number of input files:  1062
# Data has been written to config_s813.json
# Number of input files:  1062
# Data has been written to config_s814.json
# Number of input files:  1062
# Data has been written to config_s815.json
# Number of input files:  1062
# Data has been written to config_s816.json
# Number of input files:  1062
# Data has been written to config_s817.json
# Number of input files:  1062
# Data has been written to config_s818.json
# Number of input files:  1062
# Data has been written to config_s819.json
# Number of input files:  1062
# Data has been written to config_s820.json
# Number of input files:  1062
# Data has been written to config_s821.json
# Number of input files:  1062
# Data has been written to config_s822.json
# Number of input files:  1062
# Data has been written to config_s823.json
# Number of input files:  1062
# Data has been written to config_s824.json
# Number of input files:  1062
# Data has been written to config_s825.json
# Number of input files:  1062
# Data has been written to config_s826.json
# Number of input files:  1062
# Data has been written to config_s827.json
# Number of input files:  1062
# Data has been written to config_s828.json
# Number of input files:  1062
# Data has been written to config_s829.json
# Number of input files:  1062
# Data has been written to config_s830.json
# Number of input files:  1062
# Data has been written to config_s831.json
# Number of input files:  1062
# Data has been written to config_s832.json
# Number of input files:  1062
# Data has been written to config_s833.json
# Number of input files:  1062
# Data has been written to config_s834.json
# Number of input files:  1062
# Data has been written to config_s835.json
# Number of input files:  1062
# Data has been written to config_s836.json
# Number of input files:  1062
# Data has been written to config_s837.json
# Number of input files:  1062
# Data has been written to config_s838.json
# Number of input files:  1062
# Data has been written to config_s839.json
# Number of input files:  1062
# Data has been written to config_s840.json
# Number of input files:  1062
# Data has been written to config_s841.json
# Number of input files:  1062
# Data has been written to config_s842.json
# Number of input files:  1062
# Data has been written to config_s843.json
# Number of input files:  1062
# Data has been written to config_s844.json
# Number of input files:  1062
# Data has been written to config_s845.json
# Number of input files:  1062
# Data has been written to config_s846.json
# Number of input files:  1062
# Data has been written to config_s847.json
# Number of input files:  1062
# Data has been written to config_s848.json
# Number of input files:  1062
# Data has been written to config_s849.json
# Number of input files:  1062
# Data has been written to config_s850.json
# Number of input files:  1062
# Data has been written to config_s851.json
# Number of input files:  1062
# Data has been written to config_s852.json
# Number of input files:  1062
# Data has been written to config_s853.json
# Number of input files:  1062
# Data has been written to config_s854.json
# Number of input files:  1062
# Data has been written to config_s855.json
# Number of input files:  1062
# Data has been written to config_s856.json
# Number of input files:  1062
# Data has been written to config_s857.json
# Number of input files:  1062
# Data has been written to config_s858.json
# Number of input files:  1062
# Data has been written to config_s859.json
# Number of input files:  1062
# Data has been written to config_s860.json
# Number of input files:  1062
# Data has been written to config_s861.json
# Number of input files:  1062
# Data has been written to config_s862.json
# Number of input files:  1062
# Data has been written to config_s863.json
# Number of input files:  1062
# Data has been written to config_s864.json
# Number of input files:  1062
# Data has been written to config_s865.json
# Number of input files:  1062
# Data has been written to config_s866.json
# Number of input files:  1062
# Data has been written to config_s867.json
# Number of input files:  1062
# Data has been written to config_s868.json
# Number of input files:  1062
# Data has been written to config_s869.json
# Number of input files:  1062
# Data has been written to config_s870.json
# Number of input files:  1062
# Data has been written to config_s871.json
# Number of input files:  1062
# Data has been written to config_s872.json
# Number of input files:  1062
# Data has been written to config_s873.json
# Number of input files:  1062
# Data has been written to config_s874.json
# Number of input files:  1062
# Data has been written to config_s875.json
# Number of input files:  1062
# Data has been written to config_s876.json
# Number of input files:  1062
# Data has been written to config_s877.json
# Number of input files:  1062
# Data has been written to config_s878.json
# Number of input files:  1062
# Data has been written to config_s879.json
# Number of input files:  1062
# Data has been written to config_s880.json
# Number of input files:  1062
# Data has been written to config_s881.json
# Number of input files:  1062
# Data has been written to config_s882.json
# Number of input files:  1062
# Data has been written to config_s883.json
# Number of input files:  1062
# Data has been written to config_s884.json
# Number of input files:  1062
# Data has been written to config_s885.json
# Number of input files:  1062
# Data has been written to config_s886.json
# Number of input files:  1062
# Data has been written to config_s887.json
# Number of input files:  1062
# Data has been written to config_s888.json
# Number of input files:  1062
# Data has been written to config_s889.json
# Number of input files:  1062
# Data has been written to config_s890.json
# Number of input files:  1062
# Data has been written to config_s891.json
# Number of input files:  1062
# Data has been written to config_s892.json
# Number of input files:  1062
# Data has been written to config_s893.json
# Number of input files:  1062
# Data has been written to config_s894.json
# Number of input files:  1062
# Data has been written to config_s895.json
# Number of input files:  1062
# Data has been written to config_s896.json
# Number of input files:  1062
# Data has been written to config_s897.json
# Number of input files:  1062
# Data has been written to config_s898.json
# Number of input files:  1062
# Data has been written to config_s899.json
# Number of input files:  1062
# Data has been written to config_s900.json
# Number of input files:  1062
# Data has been written to config_s901.json
# Number of input files:  1062
# Data has been written to config_s902.json
# Number of input files:  1062
# Data has been written to config_s903.json
# Number of input files:  1062
# Data has been written to config_s904.json
# Number of input files:  1062
# Data has been written to config_s905.json
# Number of input files:  1062
# Data has been written to config_s906.json
# Number of input files:  1062
# Data has been written to config_s907.json
# Number of input files:  1062
# Data has been written to config_s908.json
# Number of input files:  1062
# Data has been written to config_s909.json
# Number of input files:  1062
# Data has been written to config_s910.json
# Number of input files:  1062
# Data has been written to config_s911.json
# Number of input files:  1062
# Data has been written to config_s912.json
# Number of input files:  1062
# Data has been written to config_s913.json
# Number of input files:  1062
# Data has been written to config_s914.json
# Number of input files:  1062
# Data has been written to config_s915.json
# Number of input files:  1062
# Data has been written to config_s916.json
# Number of input files:  1062
# Data has been written to config_s917.json
# Number of input files:  1062
# Data has been written to config_s918.json
# Number of input files:  1062
# Data has been written to config_s919.json
# Number of input files:  1062
# Data has been written to config_s920.json
# Number of input files:  1062
# Data has been written to config_s921.json
# Number of input files:  1062
# Data has been written to config_s922.json
# Number of input files:  1062
# Data has been written to config_s923.json
# Number of input files:  1062
# Data has been written to config_s924.json
# Number of input files:  1062
# Data has been written to config_s925.json
# Number of input files:  1062
# Data has been written to config_s926.json
# Number of input files:  1062
# Data has been written to config_s927.json
# Number of input files:  1062
# Data has been written to config_s928.json
# Number of input files:  1062
# Data has been written to config_s929.json
# Number of input files:  1062
# Data has been written to config_s930.json
# Number of input files:  1062
# Data has been written to config_s931.json
# Number of input files:  1062
# Data has been written to config_s932.json
# Number of input files:  1062
# Data has been written to config_s933.json
# Number of input files:  1062
# Data has been written to config_s934.json
# Number of input files:  1062
# Data has been written to config_s935.json
# Number of input files:  1062
# Data has been written to config_s936.json
# Number of input files:  1062
# Data has been written to config_s937.json
# Number of input files:  1062
# Data has been written to config_s938.json
# Number of input files:  1062
# Data has been written to config_s939.json
# Number of input files:  1062
# Data has been written to config_s940.json
# Number of input files:  1062
# Data has been written to config_s941.json
# Number of input files:  1062
# Data has been written to config_s942.json
# Number of input files:  1062
# Data has been written to config_s943.json
# Number of input files:  1062
# Data has been written to config_s944.json
# Number of input files:  1062
# Data has been written to config_s945.json
# Number of input files:  1062
# Data has been written to config_s946.json
# Number of input files:  1062
# Data has been written to config_s947.json
# Number of input files:  1062
# Data has been written to config_s948.json
# Number of input files:  1062
# Data has been written to config_s949.json
# Number of input files:  1062
# Data has been written to config_s950.json
# Number of input files:  1062
# Data has been written to config_s951.json
# Number of input files:  1062
# Data has been written to config_s952.json
# Number of input files:  1062
# Data has been written to config_s953.json
# Number of input files:  1062
# Data has been written to config_s954.json
# Number of input files:  1062
# Data has been written to config_s955.json
# Number of input files:  1062
# Data has been written to config_s956.json
# Number of input files:  1062
# Data has been written to config_s957.json
# Number of input files:  1062
# Data has been written to config_s958.json
# Number of input files:  1062
# Data has been written to config_s959.json
# Number of input files:  1062
# Data has been written to config_s960.json
# Number of input files:  1062
# Data has been written to config_s961.json
# Number of input files:  1062
# Data has been written to config_s962.json
# Number of input files:  1062
# Data has been written to config_s963.json
# Number of input files:  1062
# Data has been written to config_s964.json
# Number of input files:  1062
# Data has been written to config_s965.json
# Number of input files:  1062
# Data has been written to config_s966.json
# Number of input files:  1062
# Data has been written to config_s967.json
# Number of input files:  1062
# Data has been written to config_s968.json
# Number of input files:  1062
# Data has been written to config_s969.json
# Number of input files:  1062
# Data has been written to config_s970.json
# Number of input files:  1062
# Data has been written to config_s971.json
# Number of input files:  1062
# Data has been written to config_s972.json
# Number of input files:  1062
# Data has been written to config_s973.json
# Number of input files:  1062
# Data has been written to config_s974.json
# Number of input files:  1062
# Data has been written to config_s975.json
# Number of input files:  1062
# Data has been written to config_s976.json
# Number of input files:  1062
# Data has been written to config_s977.json
# Number of input files:  1062
# Data has been written to config_s978.json
# Number of input files:  1062
# Data has been written to config_s979.json
# Number of input files:  1062
# Data has been written to config_s980.json
# Number of input files:  1062
# Data has been written to config_s981.json
# Number of input files:  1062
# Data has been written to config_s982.json
# Number of input files:  1062
# Data has been written to config_s983.json
# Number of input files:  1062
# Data has been written to config_s984.json
# Number of input files:  1062
# Data has been written to config_s985.json
# Number of input files:  1062
# Data has been written to config_s986.json
# Number of input files:  1062
# Data has been written to config_s987.json
# Number of input files:  1062
# Data has been written to config_s988.json
# Number of input files:  1062
# Data has been written to config_s989.json
# Number of input files:  1062
# Data has been written to config_s990.json
# Number of input files:  1062
# Data has been written to config_s991.json
# Number of input files:  1062
# Data has been written to config_s992.json
# Number of input files:  1062
# Data has been written to config_s993.json
# Number of input files:  1062
# Data has been written to config_s994.json
# Number of input files:  1062
# Data has been written to config_s995.json
# Number of input files:  1062
# Data has been written to config_s996.json
# Number of input files:  1062
# Data has been written to config_s997.json
# Number of input files:  1062
# Data has been written to config_s998.json
# Number of input files:  1062
# Data has been written to config_s999.json
# Number of input files:  1062
# Data has been written to config_s1000.json
